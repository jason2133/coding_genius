# %%
import math

# 라이브러리 불러오기

# %%
def twocha(a, b, c):

  if (b*b - 4*a*c > 0):
    print("방정식 : %dx^2 + %dx + %d" % (a, b, c))
    print("2개의 근이 있구나!")
    print((-b + math.sqrt((b * b) - (4 * a * c))) / (2 * a))
    print((-b - math.sqrt((b * b) - (4 * a * c))) / (2 * a))
    
  elif (b*b - 4*a*c == 0):
    print("방정식 : %dx^2 + %dx + %d" % (a, b, c))
    print("중근이구나!")
    print((-b + math.sqrt((b * b) - (4 * a * c))) / (2 * a))
  
  elif (b*b - 4*a*c < 0):
    print("방정식 : %dx^2 + %dx + %d" % (a, b, c))
    print("실근이 없구나!")
    
  # elif (b*b - 4*a*c < 0): 의 경우 else로 처리 가능
  # else:
    # print("방정식 : %dx^2 + %dx + %d)" % (a, b, c))
    # print("실근이 없구나!")

# %%
twocha(1, -6, 8)
# Out:
# 방정식 : 1x^2 + -6x + 8
# 2개의 근이 있구나!
# 4.0
# 2.0

# %%
twocha(1, -4, 4)
# Out:
# 방정식 : 1x^2 + -4x + 4
# 중근이구나!
# 2.0

# %%
twocha(500, 1, 1)
# Out:
# 방정식 : 500x^2 + 1x + 1
# 실근이 없구나!
