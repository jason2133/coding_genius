# %%
import datetime

x,y= input().split() # Data Input

dayStr =["MON", "TUE", "WED", "THU", "FRI", "SAT", "SUN"]

print(dayStr[datetime.datetime(2007,int(x),int(y)).weekday()])
# Out:
# 5 23
# WED

# %% [markdown]
# #### 5월 23일은 수요일
